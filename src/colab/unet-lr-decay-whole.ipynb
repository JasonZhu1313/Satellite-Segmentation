# %%
BATCHSIZE = 21
INITIAL_LEARNING_RATE = 1e-3
LOOKBACK_EPOCHS = 2

# %%
# download data
import os
from glob import glob
os.chdir('/content/')
# !rm -rf Satellite-Segmentation
# !git clone https://github.com/JasonChu1313/Satellite-Segmentation.git
import os 
os.chdir('/content/Satellite-Segmentation')
# !mkdir /root/.kaggle/
# !mv kaggle.json /root/.kaggle/

# !kaggle competitions download -c comp-540-spring-2019
# !mkdir data
# !mv train.zip ./data/
# !mv val.zip ./data/
os.chdir("./data")
# !unzip val.zip
# !unzip train.zip
# Out:
# Cloning into 'Satellite-Segmentation'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 488 (delta 2), reused 0 (delta 0), pack-reused 482
# Receiving objects: 100% (488/488), 835.99 KiB | 2.02 MiB/s, done.
# Resolving deltas: 100% (325/325), done.
# mkdir: cannot create directory ‘/root/.kaggle/’: File exists
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading train.csv.zip to /content/Satellite-Segmentation
#  22% 5.00M/22.5M [00:00<00:00, 31.7MB/s]
# 100% 22.5M/22.5M [00:00<00:00, 89.4MB/s]
# Downloading train.zip to /content/Satellite-Segmentation
#  99% 464M/470M [00:03<00:00, 175MB/s]
# 100% 470M/470M [00:03<00:00, 152MB/s]
# Downloading val.zip to /content/Satellite-Segmentation
#  86% 76.0M/88.6M [00:00<00:00, 73.9MB/s]
# 100% 88.6M/88.6M [00:00<00:00, 127MB/s]
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  val.zip
#    creating: val/
#   inflating: val/68707_sat.jpg
#   inflating: val/68711_sat.jpg
#   inflating: val/68720_sat.jpg
#   inflating: val/68729_sat.jpg
#   inflating: val/68731_sat.jpg
#   inflating: val/68733_sat.jpg
#   inflating: val/68738_sat.jpg
#   inflating: val/68743_sat.jpg
#   inflating: val/68752_sat.jpg
#   inflating: val/68756_sat.jpg
#   inflating: val/68763_sat.jpg
#   inflating: val/68764_sat.jpg
#   inflating: val/68768_sat.jpg
#   inflating: val/68775_sat.jpg
#   inflating: val/68782_sat.jpg
#   inflating: val/68784_sat.jpg
#   inflating: val/68790_sat.jpg
#   inflating: val/68792_sat.jpg
#   inflating: val/68800_sat.jpg
#   inflating: val/68803_sat.jpg
#   inflating: val/68809_sat.jpg
#   inflating: val/68815_sat.jpg
#   inflating: val/68820_sat.jpg
#   inflating: val/68826_sat.jpg
#   inflating: val/68830_sat.jpg
#   inflating: val/68838_sat.jpg
#   inflating: val/68847_sat.jpg
#   inflating: val/68848_sat.jpg
#   inflating: val/68851_sat.jpg
#   inflating: val/68855_sat.jpg
#   inflating: val/68858_sat.jpg
#   inflating: val/68865_sat.jpg
#   inflating: val/68871_sat.jpg
#   inflating: val/68876_sat.jpg
#   inflating: val/68883_sat.jpg
#   inflating: val/68890_sat.jpg
#   inflating: val/68896_sat.jpg
#   inflating: val/68897_sat.jpg
#   inflating: val/68901_sat.jpg
#   inflating: val/68903_sat.jpg
#   inflating: val/68910_sat.jpg
#   inflating: val/68919_sat.jpg
#   inflating: val/68928_sat.jpg
#   inflating: val/68937_sat.jpg
#   inflating: val/68945_sat.jpg
#   inflating: val/68951_sat.jpg
#   inflating: val/68956_sat.jpg
#   inflating: val/68965_sat.jpg
#   inflating: val/68966_sat.jpg
#   inflating: val/68970_sat.jpg
#   inflating: val/68976_sat.jpg
#   inflating: val/68983_sat.jpg
#   inflating: val/68990_sat.jpg
#   inflating: val/68995_sat.jpg
#   inflating: val/69000_sat.jpg
#   inflating: val/69005_sat.jpg
#   inflating: val/69011_sat.jpg
#   inflating: val/69015_sat.jpg
#   inflating: val/69021_sat.jpg
#   inflating: val/69029_sat.jpg
#   inflating: val/69033_sat.jpg
#   inflating: val/69037_sat.jpg
#   inflating: val/69038_sat.jpg
#   inflating: val/69043_sat.jpg
#   inflating: val/69046_sat.jpg
#   inflating: val/69048_sat.jpg
#   inflating: val/69050_sat.jpg
#   inflating: val/69052_sat.jpg
#   inflating: val/69056_sat.jpg
#   inflating: val/69059_sat.jpg
#   inflating: val/69068_sat.jpg
#   inflating: val/69076_sat.jpg
#   inflating: val/69078_sat.jpg
#   inflating: val/69081_sat.jpg
#   inflating: val/69087_sat.jpg
#   inflating: val/69092_sat.jpg
#   inflating: val/69096_sat.jpg
#   inflating: val/69098_sat.jpg
#   inflating: val/69105_sat.jpg
#   inflating: val/69110_sat.jpg
#   inflating: val/69114_sat.jpg
#   inflating: val/69118_sat.jpg
#   inflating: val/69121_sat.jpg
#   inflating: val/69123_sat.jpg
#   inflating: val/69126_sat.jpg
#   inflating: val/69129_sat.jpg
#   inflating: val/69130_sat.jpg
#   inflating: val/69133_sat.jpg
#   inflating: val/69136_sat.jpg
#   inflating: val/69144_sat.jpg
#   inflating: val/69152_sat.jpg
#   inflating: val/69158_sat.jpg
#   inflating: val/69167_sat.jpg
#   inflating: val/69169_sat.jpg
#   inflating: val/69175_sat.jpg
#   inflating: val/69178_sat.jpg
#   inflating: val/69183_sat.jpg
#   inflating: val/69192_sat.jpg
#   inflating: val/69201_sat.jpg
#   inflating: val/69203_sat.jpg
#   inflating: val/69209_sat.jpg
#   inflating: val/69215_sat.jpg
#   inflating: val/69219_sat.jpg
#   inflating: val/69224_sat.jpg
#   inflating: val/69230_sat.jpg
#   inflating: val/69232_sat.jpg
#   inflating: val/69241_sat.jpg
#   inflating: val/69243_sat.jpg
#   inflating: val/69246_sat.jpg
#   inflating: val/69255_sat.jpg
#   inflating: val/69257_sat.jpg
#   inflating: val/69258_sat.jpg
#   inflating: val/69261_sat.jpg
#   inflating: val/69268_sat.jpg
#   inflating: val/69274_sat.jpg
#   inflating: val/69281_sat.jpg
#   inflating: val/69284_sat.jpg
#   inflating: val/69287_sat.jpg
#   inflating: val/69296_sat.jpg
#   inflating: val/69297_sat.jpg
#   inflating: val/69301_sat.jpg
#   inflating: val/69305_sat.jpg
#   inflating: val/69306_sat.jpg
#   inflating: val/69315_sat.jpg
#   inflating: val/69320_sat.jpg
#   inflating: val/69325_sat.jpg
#   inflating: val/69328_sat.jpg
#   inflating: val/69333_sat.jpg
#   inflating: val/69334_sat.jpg
#   inflating: val/69340_sat.jpg
#   inflating: val/69344_sat.jpg
#   inflating: val/69351_sat.jpg
#   inflating: val/69356_sat.jpg
#   inflating: val/69364_sat.jpg
#   inflating: val/69366_sat.jpg
#   inflating: val/69374_sat.jpg
#   inflating: val/69383_sat.jpg
#   inflating: val/69388_sat.jpg
#   inflating: val/69397_sat.jpg
#   inflating: val/69403_sat.jpg
#   inflating: val/69409_sat.jpg
#   inflating: val/69415_sat.jpg
#   inflating: val/69418_sat.jpg
#   inflating: val/69419_sat.jpg
#   inflating: val/69420_sat.jpg
#   inflating: val/69428_sat.jpg
#   inflating: val/69432_sat.jpg
#   inflating: val/69438_sat.jpg
#   inflating: val/69441_sat.jpg
#   inflating: val/69449_sat.jpg
#   inflating: val/69457_sat.jpg
#   inflating: val/69459_sat.jpg
#   inflating: val/69464_sat.jpg
#   inflating: val/69465_sat.jpg
#   inflating: val/69467_sat.jpg
#   inflating: val/69473_sat.jpg
#   inflating: val/69477_sat.jpg
#   inflating: val/69478_sat.jpg
#   inflating: val/69479_sat.jpg
#   inflating: val/69484_sat.jpg
#   inflating: val/69492_sat.jpg
#   inflating: val/69496_sat.jpg
#   inflating: val/69499_sat.jpg
#   inflating: val/69503_sat.jpg
#   inflating: val/69510_sat.jpg
#   inflating: val/69519_sat.jpg
#   inflating: val/69525_sat.jpg
#   inflating: val/69531_sat.jpg
#   inflating: val/69537_sat.jpg
#   inflating: val/69544_sat.jpg
#   inflating: val/69550_sat.jpg
#   inflating: val/69556_sat.jpg
#   inflating: val/69565_sat.jpg
#   inflating: val/69569_sat.jpg
#   inflating: val/69573_sat.jpg
#   inflating: val/69579_sat.jpg
#   inflating: val/69587_sat.jpg
#   inflating: val/69589_sat.jpg
#   inflating: val/69592_sat.jpg
#   inflating: val/69595_sat.jpg
#   inflating: val/69602_sat.jpg
#   inflating: val/69608_sat.jpg
#   inflating: val/69614_sat.jpg
#   inflating: val/69618_sat.jpg
#   inflating: val/69619_sat.jpg
#   inflating: val/69624_sat.jpg
#   inflating: val/69625_sat.jpg
#   inflating: val/69633_sat.jpg
#   inflating: val/69637_sat.jpg
#   inflating: val/69644_sat.jpg
#   inflating: val/69648_sat.jpg
#   inflating: val/69653_sat.jpg
#   inflating: val/69657_sat.jpg
#   inflating: val/69662_sat.jpg
#   inflating: val/69665_sat.jpg
#   inflating: val/69671_sat.jpg
#   inflating: val/69672_sat.jpg
#   inflating: val/69680_sat.jpg
#   inflating: val/69683_sat.jpg
#   inflating: val/69689_sat.jpg
#   inflating: val/69691_sat.jpg
#   inflating: val/69696_sat.jpg
#   inflating: val/69700_sat.jpg
#   inflating: val/69703_sat.jpg
#   inflating: val/69707_sat.jpg
#   inflating: val/69715_sat.jpg
#   inflating: val/69716_sat.jpg
#   inflating: val/69717_sat.jpg
#   inflating: val/69721_sat.jpg
#   inflating: val/69722_sat.jpg
#   inflating: val/69727_sat.jpg
#   inflating: val/69734_sat.jpg
#   inflating: val/69735_sat.jpg
#   inflating: val/69743_sat.jpg
#   inflating: val/69746_sat.jpg
#   inflating: val/69751_sat.jpg
#   inflating: val/69757_sat.jpg
#   inflating: val/69762_sat.jpg
#   inflating: val/69765_sat.jpg
#   inflating: val/69773_sat.jpg
#   inflating: val/69782_sat.jpg
#   inflating: val/69784_sat.jpg
#   inflating: val/69789_sat.jpg
#   inflating: val/69797_sat.jpg
#   inflating: val/69800_sat.jpg
#   inflating: val/69804_sat.jpg
#   inflating: val/69812_sat.jpg
#   inflating: val/69819_sat.jpg
#   inflating: val/69828_sat.jpg
#   inflating: val/69836_sat.jpg
#   inflating: val/69842_sat.jpg
#   inflating: val/69843_sat.jpg
#   inflating: val/69845_sat.jpg
#   inflating: val/69848_sat.jpg
#   inflating: val/69853_sat.jpg
#   inflating: val/69862_sat.jpg
#   inflating: val/69868_sat.jpg
#   inflating: val/69872_sat.jpg
#   inflating: val/69881_sat.jpg
#   inflating: val/69887_sat.jpg
#   inflating: val/69890_sat.jpg
#   inflating: val/69899_sat.jpg
#   inflating: val/69903_sat.jpg
#   inflating: val/69904_sat.jpg
#   inflating: val/69912_sat.jpg
#   inflating: val/69916_sat.jpg
#   inflating: val/69921_sat.jpg
#   inflating: val/69929_sat.jpg
#   inflating: val/69934_sat.jpg
#   inflating: val/69935_sat.jpg
#   inflating: val/69944_sat.jpg
#   inflating: val/69945_sat.jpg
#   inflating: val/69953_sat.jpg
#   inflating: val/69960_sat.jpg
#   inflating: val/69965_sat.jpg
#   inflating: val/69968_sat.jpg
#   inflating: val/69973_sat.jpg
#   inflating: val/69974_sat.jpg
#   inflating: val/69976_sat.jpg
#   inflating: val/69984_sat.jpg
#   inflating: val/69989_sat.jpg
#   inflating: val/69992_sat.jpg
#   inflating: val/69998_sat.jpg
#   inflating: val/69999_sat.jpg
#   inflating: val/70007_sat.jpg
#   inflating: val/70009_sat.jpg
#   inflating: val/70014_sat.jpg
#   inflating: val/70016_sat.jpg
#   inflating: val/70018_sat.jpg
#   inflating: val/70027_sat.jpg
#   inflating: val/70035_sat.jpg
#   inflating: val/70036_sat.jpg
#   inflating: val/70037_sat.jpg
#   inflating: val/70044_sat.jpg
#   inflating: val/70052_sat.jpg
#   inflating: val/70053_sat.jpg
#   inflating: val/70054_sat.jpg
#   inflating: val/70057_sat.jpg
#   inflating: val/70063_sat.jpg
#   inflating: val/70072_sat.jpg
#   inflating: val/70078_sat.jpg
#   inflating: val/70081_sat.jpg
#   inflating: val/70088_sat.jpg
#   inflating: val/70096_sat.jpg
#   inflating: val/70101_sat.jpg
#   inflating: val/70108_sat.jpg
#   inflating: val/70113_sat.jpg
#   inflating: val/70120_sat.jpg
#   inflating: val/70121_sat.jpg
#   inflating: val/70129_sat.jpg
#   inflating: val/70132_sat.jpg
#   inflating: val/70141_sat.jpg
#   inflating: val/70145_sat.jpg
#   inflating: val/70154_sat.jpg
#   inflating: val/70161_sat.jpg
#   inflating: val/70168_sat.jpg
#   inflating: val/70169_sat.jpg
#   inflating: val/70170_sat.jpg
#   inflating: val/70174_sat.jpg
#   inflating: val/70182_sat.jpg
#   inflating: val/70185_sat.jpg
#   inflating: val/70192_sat.jpg
#   inflating: val/70200_sat.jpg
#   inflating: val/70203_sat.jpg
#   inflating: val/70206_sat.jpg
#   inflating: val/70212_sat.jpg
#   inflating: val/70217_sat.jpg
#   inflating: val/70226_sat.jpg
#   inflating: val/70229_sat.jpg
#   inflating: val/70234_sat.jpg
#   inflating: val/70240_sat.jpg
#   inflating: val/70248_sat.jpg
#   inflating: val/70253_sat.jpg
#   inflating: val/70255_sat.jpg
#   inflating: val/70264_sat.jpg
#   inflating: val/70273_sat.jpg
#   inflating: val/70282_sat.jpg
#   inflating: val/70289_sat.jpg
#   inflating: val/70298_sat.jpg
#   inflating: val/70299_sat.jpg
#   inflating: val/70303_sat.jpg
#   inflating: val/70312_sat.jpg
#   inflating: val/70313_sat.jpg
#   inflating: val/70315_sat.jpg
#   inflating: val/70323_sat.jpg
#   inflating: val/70329_sat.jpg
#   inflating: val/70335_sat.jpg
#   inflating: val/70342_sat.jpg
#   inflating: val/70345_sat.jpg
#   inflating: val/70349_sat.jpg
#   inflating: val/70353_sat.jpg
#   inflating: val/70358_sat.jpg
#   inflating: val/70360_sat.jpg
#   inflating: val/70368_sat.jpg
#   inflating: val/70374_sat.jpg
#   inflating: val/70383_sat.jpg
#   inflating: val/70389_sat.jpg
#   inflating: val/70397_sat.jpg
#   inflating: val/70405_sat.jpg
#   inflating: val/70413_sat.jpg
#   inflating: val/70418_sat.jpg
#   inflating: val/70423_sat.jpg
#   inflating: val/70431_sat.jpg
#   inflating: val/70437_sat.jpg
#   inflating: val/70442_sat.jpg
#   inflating: val/70451_sat.jpg
#   inflating: val/70458_sat.jpg
#   inflating: val/70465_sat.jpg
#   inflating: val/70466_sat.jpg
#   inflating: val/70469_sat.jpg
#   inflating: val/70477_sat.jpg
#   inflating: val/70485_sat.jpg
#   inflating: val/70492_sat.jpg
#   inflating: val/70500_sat.jpg
#   inflating: val/70501_sat.jpg
#   inflating: val/70506_sat.jpg
#   inflating: val/70507_sat.jpg
#   inflating: val/70512_sat.jpg
#   inflating: val/70513_sat.jpg
#   inflating: val/70516_sat.jpg
#   inflating: val/70521_sat.jpg
#   inflating: val/70525_sat.jpg
#   inflating: val/70530_sat.jpg
#   inflating: val/70531_sat.jpg
#   inflating: val/70538_sat.jpg
#   inflating: val/70540_sat.jpg
#   inflating: val/70545_sat.jpg
#   inflating: val/70552_sat.jpg
#   inflating: val/70555_sat.jpg
#   inflating: val/70563_sat.jpg
#   inflating: val/70569_sat.jpg
#   inflating: val/70571_sat.jpg
#   inflating: val/70573_sat.jpg
#   inflating: val/70579_sat.jpg
#   inflating: val/70587_sat.jpg
#   inflating: val/70589_sat.jpg
#   inflating: val/70597_sat.jpg
#   inflating: val/70603_sat.jpg
#   inflating: val/70610_sat.jpg
#   inflating: val/70617_sat.jpg
#   inflating: val/70624_sat.jpg
#   inflating: val/70625_sat.jpg
#   inflating: val/70627_sat.jpg
#   inflating: val/70633_sat.jpg
#   inflating: val/70637_sat.jpg
#   inflating: val/70641_sat.jpg
#   inflating: val/70650_sat.jpg
#   inflating: val/70657_sat.jpg
#   inflating: val/70666_sat.jpg
#   inflating: val/70674_sat.jpg
#   inflating: val/70676_sat.jpg
#   inflating: val/70679_sat.jpg
#   inflating: val/70684_sat.jpg
#   inflating: val/70691_sat.jpg
#   inflating: val/70699_sat.jpg
#   inflating: val/70703_sat.jpg
#   inflating: val/70710_sat.jpg
#   inflating: val/70715_sat.jpg
#   inflating: val/70719_sat.jpg
#   inflating: val/70723_sat.jpg
#   inflating: val/70732_sat.jpg
#   inflating: val/70741_sat.jpg
#   inflating: val/70748_sat.jpg
#   inflating: val/70755_sat.jpg
#   inflating: val/70756_sat.jpg
#   inflating: val/70761_sat.jpg
#   inflating: val/70765_sat.jpg
#   inflating: val/70774_sat.jpg
#   inflating: val/70777_sat.jpg
#   inflating: val/70786_sat.jpg
#   inflating: val/70787_sat.jpg
#   inflating: val/70791_sat.jpg
#   inflating: val/70800_sat.jpg
#   inflating: val/70805_sat.jpg
#   inflating: val/70808_sat.jpg
#   inflating: val/70816_sat.jpg
#   inflating: val/70825_sat.jpg
#   inflating: val/70830_sat.jpg
#   inflating: val/70834_sat.jpg
#   inflating: val/70836_sat.jpg
#   inflating: val/70842_sat.jpg
#   inflating: val/70848_sat.jpg
#   inflating: val/70853_sat.jpg
#   inflating: val/70862_sat.jpg
#   inflating: val/70871_sat.jpg
#   inflating: val/70879_sat.jpg
#   inflating: val/70885_sat.jpg
#   inflating: val/70887_sat.jpg
#   inflating: val/70890_sat.jpg
#   inflating: val/70891_sat.jpg
#   inflating: val/70894_sat.jpg
#   inflating: val/70898_sat.jpg
#   inflating: val/70899_sat.jpg
#   inflating: val/70902_sat.jpg
#   inflating: val/70908_sat.jpg
#   inflating: val/70912_sat.jpg
#   inflating: val/70921_sat.jpg
#   inflating: val/70927_sat.jpg
#   inflating: val/70936_sat.jpg
#   inflating: val/70941_sat.jpg
#   inflating: val/70949_sat.jpg
#   inflating: val/70952_sat.jpg
#   inflating: val/70958_sat.jpg
#   inflating: val/70961_sat.jpg
#   inflating: val/70970_sat.jpg
#   inflating: val/70976_sat.jpg
#   inflating: val/70977_sat.jpg
#   inflating: val/70983_sat.jpg
#   inflating: val/70990_sat.jpg
#   inflating: val/70992_sat.jpg
#   inflating: val/70998_sat.jpg
#   inflating: val/70999_sat.jpg
#   inflating: val/71001_sat.jpg
#   inflating: val/71007_sat.jpg
#   inflating: val/71010_sat.jpg
#   inflating: val/71018_sat.jpg
#   inflating: val/71021_sat.jpg
#   inflating: val/71022_sat.jpg
#   inflating: val/71029_sat.jpg
#   inflating: val/71038_sat.jpg
#   inflating: val/71042_sat.jpg
#   inflating: val/71049_sat.jpg
#   inflating: val/71055_sat.jpg
#   inflating: val/71058_sat.jpg
#   inflating: val/71063_sat.jpg
#   inflating: val/71072_sat.jpg
#   inflating: val/71081_sat.jpg
#   inflating: val/71085_sat.jpg
#   inflating: val/71094_sat.jpg
#   inflating: val/71102_sat.jpg
#   inflating: val/71109_sat.jpg
#   inflating: val/71110_sat.jpg
#   inflating: val/71113_sat.jpg
#   inflating: val/71120_sat.jpg
#   inflating: val/71127_sat.jpg
#   inflating: val/71135_sat.jpg
#   inflating: val/71136_sat.jpg
#   inflating: val/71144_sat.jpg
#   inflating: val/71146_sat.jpg
#   inflating: val/71148_sat.jpg
#   inflating: val/71156_sat.jpg
#   inflating: val/71164_sat.jpg
#   inflating: val/71165_sat.jpg
#   inflating: val/71171_sat.jpg
#   inflating: val/71176_sat.jpg
#   inflating: val/71183_sat.jpg
#   inflating: val/71192_sat.jpg
#   inflating: val/71193_sat.jpg
#   inflating: val/71197_sat.jpg
#   inflating: val/71200_sat.jpg
#   inflating: val/71207_sat.jpg
#   inflating: val/71210_sat.jpg
#   inflating: val/71218_sat.jpg
#   inflating: val/71219_sat.jpg
#   inflating: val/71222_sat.jpg
#   inflating: val/71229_sat.jpg
#   inflating: val/71232_sat.jpg
#   inflating: val/71239_sat.jpg
#   inflating: val/71246_sat.jpg
#   inflating: val/71253_sat.jpg
#   inflating: val/71254_sat.jpg
#   inflating: val/71261_sat.jpg
#   inflating: val/71266_sat.jpg
#   inflating: val/71271_sat.jpg
#   inflating: val/71273_sat.jpg
#   inflating: val/71278_sat.jpg
#   inflating: val/71284_sat.jpg
#   inflating: val/71286_sat.jpg
#   inflating: val/71291_sat.jpg
#   inflating: val/71294_sat.jpg
#   inflating: val/71301_sat.jpg
#   inflating: val/71310_sat.jpg
#   inflating: val/71316_sat.jpg
#   inflating: val/71324_sat.jpg
#   inflating: val/71325_sat.jpg
#   inflating: val/71333_sat.jpg
#   inflating: val/71337_sat.jpg
#   inflating: val/71345_sat.jpg
#   inflating: val/71350_sat.jpg
#   inflating: val/71358_sat.jpg
#   inflating: val/71364_sat.jpg
#   inflating: val/71373_sat.jpg
#   inflating: val/71379_sat.jpg
#   inflating: val/71388_sat.jpg
#   inflating: val/71390_sat.jpg
#   inflating: val/71391_sat.jpg
#   inflating: val/71399_sat.jpg
#   inflating: val/71402_sat.jpg
#   inflating: val/71408_sat.jpg
#   inflating: val/71415_sat.jpg
#   inflating: val/71421_sat.jpg
#   inflating: val/71423_sat.jpg
#   inflating: val/71432_sat.jpg
#   inflating: val/71433_sat.jpg
#   inflating: val/71440_sat.jpg
#   inflating: val/71443_sat.jpg
#   inflating: val/71451_sat.jpg
#   inflating: val/71454_sat.jpg
#   inflating: val/71460_sat.jpg
#   inflating: val/71461_sat.jpg
#   inflating: val/71464_sat.jpg
#   inflating: val/71470_sat.jpg
#   inflating: val/71473_sat.jpg
#   inflating: val/71476_sat.jpg
#   inflating: val/71482_sat.jpg
#   inflating: val/71488_sat.jpg
#   inflating: val/71491_sat.jpg
#   inflating: val/71497_sat.jpg
#   inflating: val/71501_sat.jpg
#   inflating: val/71502_sat.jpg
#   inflating: val/71505_sat.jpg
#   inflating: val/71507_sat.jpg
#   inflating: val/71508_sat.jpg
#   inflating: val/71511_sat.jpg
#   inflating: val/71513_sat.jpg
#   inflating: val/71514_sat.jpg
#   inflating: val/71519_sat.jpg
#   inflating: val/71520_sat.jpg
#   inflating: val/71522_sat.jpg
#   inflating: val/71523_sat.jpg
#   inflating: val/71526_sat.jpg
#   inflating: val/71527_sat.jpg
#   inflating: val/71534_sat.jpg
#   inflating: val/71541_sat.jpg
#   inflating: val/71544_sat.jpg
#   inflating: val/71545_sat.jpg
#   inflating: val/71552_sat.jpg
#   inflating: val/71557_sat.jpg
#   inflating: val/71558_sat.jpg
#   inflating: val/71562_sat.jpg
#   inflating: val/71568_sat.jpg
#   inflating: val/71576_sat.jpg
#   inflating: val/71579_sat.jpg
#   inflating: val/71581_sat.jpg
#   inflating: val/71588_sat.jpg
#   inflating: val/71590_sat.jpg
#   inflating: val/71596_sat.jpg
#   inflating: val/71600_sat.jpg
#   inflating: val/71602_sat.jpg
#   inflating: val/71609_sat.jpg
#   inflating: val/71617_sat.jpg
#   inflating: val/71623_sat.jpg
#   inflating: val/71626_sat.jpg
#   inflating: val/71629_sat.jpg
#   inflating: val/71632_sat.jpg
#   inflating: val/71634_sat.jpg
#   inflating: val/71641_sat.jpg
#   inflating: val/71644_sat.jpg
#   inflating: val/71650_sat.jpg
#   inflating: val/71656_sat.jpg
#   inflating: val/71665_sat.jpg
#   inflating: val/71667_sat.jpg
#   inflating: val/71675_sat.jpg
#   inflating: val/71678_sat.jpg
#   inflating: val/71681_sat.jpg
#   inflating: val/71688_sat.jpg
#   inflating: val/71690_sat.jpg
#   inflating: val/71695_sat.jpg
#   inflating: val/71700_sat.jpg
#   inflating: val/71703_sat.jpg
#   inflating: val/71704_sat.jpg
#   inflating: val/71713_sat.jpg
#   inflating: val/71714_sat.jpg
#   inflating: val/71716_sat.jpg
#   inflating: val/71723_sat.jpg
#   inflating: val/71727_sat.jpg
#   inflating: val/71728_sat.jpg
#   inflating: val/71735_sat.jpg
#   inflating: val/71741_sat.jpg
#   inflating: val/71745_sat.jpg
#   inflating: val/71753_sat.jpg
#   inflating: val/71757_sat.jpg
#   inflating: val/71758_sat.jpg
#   inflating: val/71764_sat.jpg
#   inflating: val/71765_sat.jpg
#   inflating: val/71767_sat.jpg
#   inflating: val/71771_sat.jpg
#   inflating: val/71778_sat.jpg
#   inflating: val/71779_sat.jpg
#   inflating: val/71784_sat.jpg
#   inflating: val/71789_sat.jpg
#   inflating: val/71791_sat.jpg
#   inflating: val/71798_sat.jpg
#   inflating: val/71805_sat.jpg
#   inflating: val/71807_sat.jpg
#   inflating: val/71812_sat.jpg
#   inflating: val/71814_sat.jpg
#   inflating: val/71822_sat.jpg
#   inflating: val/71826_sat.jpg
#   inflating: val/71835_sat.jpg
#   inflating: val/71844_sat.jpg
#   inflating: val/71852_sat.jpg
#   inflating: val/71854_sat.jpg
#   inflating: val/71863_sat.jpg
#   inflating: val/71872_sat.jpg
#   inflating: val/71879_sat.jpg
#   inflating: val/71887_sat.jpg
#   inflating: val/71889_sat.jpg
#   inflating: val/71896_sat.jpg
#   inflating: val/71905_sat.jpg
#   inflating: val/71914_sat.jpg
#   inflating: val/71918_sat.jpg
#   inflating: val/71927_sat.jpg
#   inflating: val/71929_sat.jpg
#   inflating: val/71936_sat.jpg
#   inflating: val/71939_sat.jpg
#   inflating: val/71945_sat.jpg
#   inflating: val/71948_sat.jpg
#   inflating: val/71949_sat.jpg
#   inflating: val/71956_sat.jpg
#   inflating: val/71958_sat.jpg
#   inflating: val/71960_sat.jpg
#   inflating: val/71964_sat.jpg
#   inflating: val/71970_sat.jpg
#   inflating: val/71971_sat.jpg
#   inflating: val/71979_sat.jpg
#   inflating: val/71983_sat.jpg
#   inflating: val/71986_sat.jpg
#   inflating: val/71990_sat.jpg
#   inflating: val/71998_sat.jpg
#   inflating: val/72004_sat.jpg
#   inflating: val/72012_sat.jpg
#   inflating: val/72015_sat.jpg
#   inflating: val/72022_sat.jpg
#   inflating: val/72031_sat.jpg
#   inflating: val/72040_sat.jpg
#   inflating: val/72041_sat.jpg
#   inflating: val/72043_sat.jpg
#   inflating: val/72046_sat.jpg
#   inflating: val/72053_sat.jpg
#   inflating: val/72056_sat.jpg
#   inflating: val/72063_sat.jpg
#   inflating: val/72071_sat.jpg
#   inflating: val/72075_sat.jpg
#   inflating: val/72081_sat.jpg
#   inflating: val/72086_sat.jpg
#   inflating: val/72092_sat.jpg
#   inflating: val/72097_sat.jpg
#   inflating: val/72101_sat.jpg
#   inflating: val/72105_sat.jpg
#   inflating: val/72113_sat.jpg
#   inflating: val/72120_sat.jpg
#   inflating: val/72121_sat.jpg
#   inflating: val/72126_sat.jpg
#   inflating: val/72127_sat.jpg
#   inflating: val/72133_sat.jpg
#   inflating: val/72137_sat.jpg
#   inflating: val/72144_sat.jpg
#   inflating: val/72153_sat.jpg
#   inflating: val/72157_sat.jpg
#   inflating: val/72158_sat.jpg
#   inflating: val/72164_sat.jpg
#   inflating: val/72169_sat.jpg
#   inflating: val/72173_sat.jpg
#   inflating: val/72181_sat.jpg
#   inflating: val/72185_sat.jpg
#   inflating: val/72188_sat.jpg
#   inflating: val/72191_sat.jpg
#   inflating: val/72197_sat.jpg
#   inflating: val/72204_sat.jpg
#   inflating: val/72213_sat.jpg
#   inflating: val/72221_sat.jpg
#   inflating: val/72222_sat.jpg
#   inflating: val/72225_sat.jpg
#   inflating: val/72230_sat.jpg
#   inflating: val/72234_sat.jpg
#   inflating: val/72238_sat.jpg
#   inflating: val/72247_sat.jpg
#   inflating: val/72256_sat.jpg
#   inflating: val/72261_sat.jpg
#   inflating: val/72267_sat.jpg
#   inflating: val/72276_sat.jpg
#   inflating: val/72278_sat.jpg
#   inflating: val/72287_sat.jpg
#   inflating: val/72291_sat.jpg
#   inflating: val/72297_sat.jpg
#   inflating: val/72300_sat.jpg
#   inflating: val/72306_sat.jpg
#   inflating: val/72312_sat.jpg
#   inflating: val/72314_sat.jpg
#   inflating: val/72316_sat.jpg
#   inflating: val/72325_sat.jpg
#   inflating: val/72331_sat.jpg
#   inflating: val/72340_sat.jpg
#   inflating: val/72344_sat.jpg
#   inflating: val/72351_sat.jpg
#   inflating: val/72357_sat.jpg
#   inflating: val/72360_sat.jpg
#   inflating: val/72362_sat.jpg
#   inflating: val/72363_sat.jpg
#   inflating: val/72371_sat.jpg
#   inflating: val/72377_sat.jpg
#   inflating: val/72384_sat.jpg
#   inflating: val/72392_sat.jpg
#   inflating: val/72397_sat.jpg
#   inflating: val/72405_sat.jpg
#   inflating: val/72407_sat.jpg
#   inflating: val/72414_sat.jpg
#   inflating: val/72423_sat.jpg
#   inflating: val/72430_sat.jpg
#   inflating: val/72436_sat.jpg
#   inflating: val/72440_sat.jpg
#   inflating: val/72441_sat.jpg
#   inflating: val/72442_sat.jpg
#   inflating: val/72445_sat.jpg
#   inflating: val/72450_sat.jpg
#   inflating: val/72453_sat.jpg
#   inflating: val/72461_sat.jpg
#   inflating: val/72467_sat.jpg
#   inflating: val/72474_sat.jpg
#   inflating: val/72476_sat.jpg
#   inflating: val/72482_sat.jpg
#   inflating: val/72488_sat.jpg
#   inflating: val/72491_sat.jpg
#   inflating: val/72495_sat.jpg
#   inflating: val/72502_sat.jpg
#   inflating: val/72507_sat.jpg
#   inflating: val/72510_sat.jpg
#   inflating: val/72519_sat.jpg
#   inflating: val/72528_sat.jpg
#   inflating: val/72529_sat.jpg
#   inflating: val/72530_sat.jpg
#   inflating: val/72537_sat.jpg
#   inflating: val/72543_sat.jpg
#   inflating: val/72552_sat.jpg
#   inflating: val/72556_sat.jpg
#   inflating: val/72564_sat.jpg
#   inflating: val/72565_sat.jpg
#   inflating: val/72568_sat.jpg
#   inflating: val/72570_sat.jpg
#   inflating: val/72579_sat.jpg
#   inflating: val/72587_sat.jpg
#   inflating: val/72596_sat.jpg
#   inflating: val/72600_sat.jpg
#   inflating: val/72606_sat.jpg
#   inflating: val/72613_sat.jpg
#   inflating: val/72614_sat.jpg
#   inflating: val/72615_sat.jpg
#   inflating: val/72617_sat.jpg
#   inflating: val/72623_sat.jpg
#   inflating: val/72625_sat.jpg
#   inflating: val/72633_sat.jpg
#   inflating: val/72641_sat.jpg
#   inflating: val/72646_sat.jpg
#   inflating: val/72655_sat.jpg
#   inflating: val/72663_sat.jpg
#   inflating: val/72669_sat.jpg
#   inflating: val/72670_sat.jpg
#   inflating: val/72678_sat.jpg
#   inflating: val/72685_sat.jpg
#   inflating: val/72690_sat.jpg
#   inflating: val/72699_sat.jpg
#   inflating: val/72703_sat.jpg
#   inflating: val/72708_sat.jpg
#   inflating: val/72715_sat.jpg
#   inflating: val/72716_sat.jpg
#   inflating: val/72719_sat.jpg
#   inflating: val/72728_sat.jpg
#   inflating: val/72731_sat.jpg
#   inflating: val/72740_sat.jpg
#   inflating: val/72748_sat.jpg
#   inflating: val/72757_sat.jpg
#   inflating: val/72761_sat.jpg
#   inflating: val/72763_sat.jpg
#   inflating: val/72765_sat.jpg
#   inflating: val/72770_sat.jpg
#   inflating: val/72778_sat.jpg
#   inflating: val/72781_sat.jpg
#   inflating: val/72784_sat.jpg
#   inflating: val/72785_sat.jpg
#   inflating: val/72794_sat.jpg
#   inflating: val/72800_sat.jpg
#   inflating: val/72808_sat.jpg
#   inflating: val/72816_sat.jpg
#   inflating: val/72822_sat.jpg
#   inflating: val/72828_sat.jpg
#   inflating: val/72833_sat.jpg
#   inflating: val/72837_sat.jpg
#   inflating: val/72841_sat.jpg
#   inflating: val/72845_sat.jpg
#   inflating: val/72849_sat.jpg
#   inflating: val/72850_sat.jpg
#   inflating: val/72858_sat.jpg
#   inflating: val/72867_sat.jpg
#   inflating: val/72873_sat.jpg
#   inflating: val/72881_sat.jpg
#   inflating: val/72883_sat.jpg
#   inflating: val/72890_sat.jpg
#   inflating: val/72896_sat.jpg
#   inflating: val/72900_sat.jpg
#   inflating: val/72902_sat.jpg
#   inflating: val/72910_sat.jpg
#   inflating: val/72919_sat.jpg
#   inflating: val/72923_sat.jpg
#   inflating: val/72932_sat.jpg
#   inflating: val/72939_sat.jpg
#   inflating: val/72941_sat.jpg
#   inflating: val/72946_sat.jpg
#   inflating: val/72950_sat.jpg
#   inflating: val/72957_sat.jpg
#   inflating: val/72958_sat.jpg
#   inflating: val/72964_sat.jpg
#   inflating: val/72967_sat.jpg
#   inflating: val/72970_sat.jpg
#   inflating: val/72976_sat.jpg
#   inflating: val/72980_sat.jpg
#   inflating: val/72982_sat.jpg
#   inflating: val/72991_sat.jpg
#   inflating: val/72997_sat.jpg
#   inflating: val/73002_sat.jpg
#   inflating: val/73004_sat.jpg
#   inflating: val/73006_sat.jpg
#   inflating: val/73010_sat.jpg
#   inflating: val/73019_sat.jpg
#   inflating: val/73027_sat.jpg
#   inflating: val/73030_sat.jpg
#   inflating: val/73034_sat.jpg
#   inflating: val/73037_sat.jpg
#   inflating: val/73044_sat.jpg
#   inflating: val/73052_sat.jpg
#   inflating: val/73057_sat.jpg
#   inflating: val/73062_sat.jpg
#   inflating: val/73070_sat.jpg
#   inflating: val/73077_sat.jpg
#   inflating: val/73086_sat.jpg
#   inflating: val/73089_sat.jpg
#   inflating: val/73091_sat.jpg
#   inflating: val/73095_sat.jpg
#   inflating: val/73102_sat.jpg
#   inflating: val/73108_sat.jpg
#   inflating: val/73115_sat.jpg
#   inflating: val/73120_sat.jpg
#   inflating: val/73125_sat.jpg
#   inflating: val/73129_sat.jpg
#   inflating: val/73131_sat.jpg
#   inflating: val/73138_sat.jpg
#   inflating: val/73143_sat.jpg
#   inflating: val/73146_sat.jpg
#   inflating: val/73151_sat.jpg
#   inflating: val/73154_sat.jpg
#   inflating: val/73157_sat.jpg
#   inflating: val/73166_sat.jpg
#   inflating: val/73172_sat.jpg
#   inflating: val/73175_sat.jpg
#   inflating: val/73181_sat.jpg
#   inflating: val/73188_sat.jpg
#   inflating: val/73192_sat.jpg
#   inflating: val/73197_sat.jpg
#   inflating: val/73200_sat.jpg
#   inflating: val/73204_sat.jpg
#   inflating: val/73208_sat.jpg
#   inflating: val/73209_sat.jpg
#   inflating: val/73212_sat.jpg
#   inflating: val/73220_sat.jpg
#   inflating: val/73223_sat.jpg
#   inflating: val/73229_sat.jpg
#   inflating: val/73237_sat.jpg
#   inflating: val/73240_sat.jpg
#   inflating: val/73247_sat.jpg
#   inflating: val/73252_sat.jpg
#   inflating: val/73255_sat.jpg
#   inflating: val/73258_sat.jpg
#   inflating: val/73264_sat.jpg
#   inflating: val/73266_sat.jpg
#   inflating: val/73269_sat.jpg
#   inflating: val/73275_sat.jpg
#   inflating: val/73284_sat.jpg
#   inflating: val/73290_sat.jpg
#   inflating: val/73299_sat.jpg
#   inflating: val/73301_sat.jpg
#   inflating: val/73307_sat.jpg
#   inflating: val/73313_sat.jpg
#   inflating: val/73314_sat.jpg
#   inflating: val/73315_sat.jpg
#   inflating: val/73322_sat.jpg
#   inflating: val/73328_sat.jpg
#   inflating: val/73331_sat.jpg
#   inflating: val/73338_sat.jpg
#   inflating: val/73340_sat.jpg
#   inflating: val/73343_sat.jpg
#   inflating: val/73344_sat.jpg
#   inflating: val/73352_sat.jpg
#   inflating: val/73360_sat.jpg
#   inflating: val/73366_sat.jpg
#   inflating: val/73367_sat.jpg
#   inflating: val/73371_sat.jpg
#   inflating: val/73377_sat.jpg
#   inflating: val/73379_sat.jpg
#   inflating: val/73386_sat.jpg
#   inflating: val/73392_sat.jpg
#   inflating: val/73397_sat.jpg
#   inflating: val/73399_sat.jpg
#   inflating: val/73406_sat.jpg
#   inflating: val/73410_sat.jpg
#   inflating: val/73414_sat.jpg
#   inflating: val/73418_sat.jpg
#   inflating: val/73423_sat.jpg
#   inflating: val/73425_sat.jpg
#   inflating: val/73426_sat.jpg
#   inflating: val/73435_sat.jpg
#   inflating: val/73436_sat.jpg
#   inflating: val/73444_sat.jpg
#   inflating: val/73453_sat.jpg
#   inflating: val/73461_sat.jpg
#   inflating: val/73470_sat.jpg
#   inflating: val/73471_sat.jpg
#   inflating: val/73474_sat.jpg
#   inflating: val/73479_sat.jpg
#   inflating: val/73486_sat.jpg
#   inflating: val/73493_sat.jpg
#   inflating: val/73495_sat.jpg
#   inflating: val/73499_sat.jpg
#   inflating: val/73502_sat.jpg
#   inflating: val/73509_sat.jpg
#   inflating: val/73513_sat.jpg
#   inflating: val/73516_sat.jpg
#   inflating: val/73522_sat.jpg
#   inflating: val/73527_sat.jpg
#   inflating: val/73534_sat.jpg
#   inflating: val/73539_sat.jpg
#   inflating: val/73544_sat.jpg
#   inflating: val/73548_sat.jpg
#   inflating: val/73556_sat.jpg
#   inflating: val/73557_sat.jpg
#   inflating: val/73564_sat.jpg
#   inflating: val/73571_sat.jpg
#   inflating: val/73573_sat.jpg
#   inflating: val/73575_sat.jpg
#   inflating: val/73576_sat.jpg
#   inflating: val/73579_sat.jpg
#   inflating: val/73581_sat.jpg
#   inflating: val/73585_sat.jpg
#   inflating: val/73594_sat.jpg
#   inflating: val/73599_sat.jpg
#   inflating: val/73602_sat.jpg
#   inflating: val/73606_sat.jpg
#   inflating: val/73613_sat.jpg
#   inflating: val/73622_sat.jpg
#   inflating: val/73625_sat.jpg
#   inflating: val/73629_sat.jpg
#   inflating: val/73634_sat.jpg
#   inflating: val/73640_sat.jpg
#   inflating: val/73647_sat.jpg
#   inflating: val/73652_sat.jpg
#   inflating: val/73653_sat.jpg
#   inflating: val/73658_sat.jpg
#   inflating: val/73665_sat.jpg
#   inflating: val/73673_sat.jpg
#   inflating: val/73682_sat.jpg
#   inflating: val/73683_sat.jpg
#   inflating: val/73690_sat.jpg
#   inflating: val/73697_sat.jpg
#   inflating: val/73698_sat.jpg
#   inflating: val/73706_sat.jpg
#   inflating: val/73714_sat.jpg
#   inflating: val/73723_sat.jpg
#   inflating: val/73724_sat.jpg
#   inflating: val/73731_sat.jpg
#   inflating: val/73739_sat.jpg
#   inflating: val/73747_sat.jpg
#   inflating: val/73756_sat.jpg
#   inflating: val/73763_sat.jpg
#   inflating: val/73769_sat.jpg
#   inflating: val/73771_sat.jpg
#   inflating: val/73775_sat.jpg
#   inflating: val/73779_sat.jpg
#   inflating: val/73784_sat.jpg
#   inflating: val/73792_sat.jpg
#   inflating: val/73799_sat.jpg
#   inflating: val/73803_sat.jpg
#   inflating: val/73806_sat.jpg
#   inflating: val/73814_sat.jpg
#   inflating: val/73822_sat.jpg
#   inflating: val/73824_sat.jpg
#   inflating: val/73833_sat.jpg
#   inflating: val/73838_sat.jpg
#   inflating: val/73846_sat.jpg
#   inflating: val/73848_sat.jpg
#   inflating: val/73856_sat.jpg
#   inflating: val/73859_sat.jpg
#   inflating: val/73860_sat.jpg
#   inflating: val/73861_sat.jpg
#   inflating: val/73869_sat.jpg
#   inflating: val/73873_sat.jpg
#   inflating: val/73874_sat.jpg
#   inflating: val/73876_sat.jpg
#   inflating: val/73878_sat.jpg
#   inflating: val/73881_sat.jpg
#   inflating: val/73886_sat.jpg
#   inflating: val/73895_sat.jpg
#   inflating: val/73900_sat.jpg
#   inflating: val/73907_sat.jpg
#   inflating: val/73915_sat.jpg
#   inflating: val/73918_sat.jpg
#   inflating: val/73922_sat.jpg
#   inflating: val/73931_sat.jpg
#   inflating: val/73933_sat.jpg
#   inflating: val/73942_sat.jpg
#   inflating: val/73944_sat.jpg
#   inflating: val/73951_sat.jpg
#   inflating: val/73953_sat.jpg
#   inflating: val/73962_sat.jpg
#   inflating: val/73965_sat.jpg
#   inflating: val/73974_sat.jpg
#   inflating: val/73979_sat.jpg
#   inflating: val/73984_sat.jpg
#   inflating: val/73990_sat.jpg
#   inflating: val/73992_sat.jpg
#   inflating: val/73995_sat.jpg
#   inflating: val/74001_sat.jpg
#   inflating: val/74008_sat.jpg
#   inflating: val/74010_sat.jpg
#   inflating: val/74015_sat.jpg
#   inflating: val/74023_sat.jpg
#   inflating: val/74032_sat.jpg
#   inflating: val/74040_sat.jpg
#   inflating: val/74043_sat.jpg
#   inflating: val/74047_sat.jpg
#   inflating: val/74052_sat.jpg
#   inflating: val/74059_sat.jpg
#   inflating: val/74066_sat.jpg
#   inflating: val/74075_sat.jpg
#   inflating: val/74077_sat.jpg
#   inflating: val/74080_sat.jpg
#   inflating: val/74081_sat.jpg
#   inflating: val/74087_sat.jpg
#   inflating: val/74091_sat.jpg
#   inflating: val/74093_sat.jpg
#   inflating: val/74102_sat.jpg
#   inflating: val/74103_sat.jpg
#   inflating: val/74106_sat.jpg
#   inflating: val/74112_sat.jpg
#   inflating: val/74118_sat.jpg
#   inflating: val/74119_sat.jpg
#   inflating: val/74123_sat.jpg
#   inflating: val/74125_sat.jpg
#   inflating: val/74132_sat.jpg
#   inflating: val/74138_sat.jpg
#   inflating: val/74141_sat.jpg
#   inflating: val/74145_sat.jpg
#   inflating: val/74147_sat.jpg
#   inflating: val/74154_sat.jpg
#   inflating: val/74156_sat.jpg
#   inflating: val/74165_sat.jpg
#   inflating: val/74174_sat.jpg
#   inflating: val/74183_sat.jpg
#   inflating: val/74190_sat.jpg
#   inflating: val/74193_sat.jpg
#   inflating: val/74194_sat.jpg
#   inflating: val/74198_sat.jpg
#   inflating: val/74203_sat.jpg
#   inflating: val/74206_sat.jpg
#   inflating: val/74211_sat.jpg
#   inflating: val/74214_sat.jpg
#   inflating: val/74219_sat.jpg
#   inflating: val/74226_sat.jpg
#   inflating: val/74233_sat.jpg
#   inflating: val/74234_sat.jpg
#   inflating: val/74235_sat.jpg
#   inflating: val/74240_sat.jpg
#   inflating: val/74243_sat.jpg
#   inflating: val/74251_sat.jpg
#   inflating: val/74259_sat.jpg
#   inflating: val/74268_sat.jpg
#   inflating: val/74272_sat.jpg
#   inflating: val/74277_sat.jpg
#   inflating: val/74284_sat.jpg
#   inflating: val/74290_sat.jpg
#   inflating: val/74295_sat.jpg
#   inflating: val/74302_sat.jpg
#   inflating: val/74307_sat.jpg
#   inflating: val/74314_sat.jpg
#   inflating: val/74320_sat.jpg
#   inflating: val/74322_sat.jpg
#   inflating: val/74328_sat.jpg
#   inflating: val/74332_sat.jpg
#   inflating: val/74339_sat.jpg
#   inflating: val/74341_sat.jpg
#   inflating: val/74348_sat.jpg
#   inflating: val/74356_sat.jpg
#   inflating: val/74357_sat.jpg
#   inflating: val/74362_sat.jpg
#   inflating: val/74364_sat.jpg
#   inflating: val/74367_sat.jpg
#   inflating: val/74373_sat.jpg
#   inflating: val/74378_sat.jpg
#   inflating: val/74382_sat.jpg
#   inflating: val/74383_sat.jpg
#   inflating: val/74385_sat.jpg
#   inflating: val/74386_sat.jpg
#   inflating: val/74392_sat.jpg
#   inflating: val/74399_sat.jpg
#   inflating: val/74408_sat.jpg
#   inflating: val/74410_sat.jpg
#   inflating: val/74419_sat.jpg
#   inflating: val/74423_sat.jpg
#   inflating: val/74425_sat.jpg
#   inflating: val/74432_sat.jpg
#   inflating: val/74441_sat.jpg
#   inflating: val/74450_sat.jpg
#   inflating: val/74459_sat.jpg
#   inflating: val/74462_sat.jpg
#   inflating: val/74469_sat.jpg
#   inflating: val/74470_sat.jpg
#   inflating: val/74475_sat.jpg
#   inflating: val/74481_sat.jpg
#   inflating: val/74487_sat.jpg
#   inflating: val/74495_sat.jpg
#   inflating: val/74502_sat.jpg
#   inflating: val/74509_sat.jpg
#   inflating: val/74510_sat.jpg
#   inflating: val/74512_sat.jpg
#   inflating: val/74521_sat.jpg
#   inflating: val/74523_sat.jpg
#   inflating: val/74532_sat.jpg
#   inflating: val/74534_sat.jpg
#   inflating: val/74539_sat.jpg
#   inflating: val/74543_sat.jpg
#   inflating: val/74545_sat.jpg
#   inflating: val/74550_sat.jpg
#   inflating: val/74551_sat.jpg
#   inflating: val/74558_sat.jpg
#   inflating: val/74567_sat.jpg
#   inflating: val/74575_sat.jpg
#   inflating: val/74584_sat.jpg
#   inflating: val/74588_sat.jpg
#   inflating: val/74592_sat.jpg
#   inflating: val/74595_sat.jpg
#   inflating: val/74597_sat.jpg
#   inflating: val/74605_sat.jpg
#   inflating: val/74609_sat.jpg
#   inflating: val/74610_sat.jpg
#   inflating: val/74613_sat.jpg
#   inflating: val/74614_sat.jpg
#   inflating: val/74616_sat.jpg
#   inflating: val/74623_sat.jpg
#   inflating: val/74631_sat.jpg
#   inflating: val/74639_sat.jpg
#   inflating: val/74646_sat.jpg
#   inflating: val/74650_sat.jpg
#   inflating: val/74659_sat.jpg
#   inflating: val/74666_sat.jpg
#   inflating: val/74668_sat.jpg
#   inflating: val/74670_sat.jpg
#   inflating: val/74676_sat.jpg
#   inflating: val/74679_sat.jpg
#   inflating: val/74687_sat.jpg
#   inflating: val/74689_sat.jpg
#   inflating: val/74695_sat.jpg
#   inflating: val/74704_sat.jpg
#   inflating: val/74706_sat.jpg
#   inflating: val/74713_sat.jpg
#   inflating: val/74720_sat.jpg
#   inflating: val/74725_sat.jpg
#   inflating: val/74730_sat.jpg
#   inflating: val/74733_sat.jpg
#   inflating: val/74740_sat.jpg
#   inflating: val/74746_sat.jpg
#   inflating: val/74751_sat.jpg
#   inflating: val/74753_sat.jpg
#   inflating: val/74762_sat.jpg
#   inflating: val/74765_sat.jpg
#   inflating: val/74767_sat.jpg
#   inflating: val/74773_sat.jpg
#   inflating: val/74778_sat.jpg
#   inflating: val/74783_sat.jpg
#   inflating: val/74791_sat.jpg
#   inflating: val/74800_sat.jpg
#   inflating: val/74807_sat.jpg
#   inflating: val/74810_sat.jpg
#   inflating: val/74819_sat.jpg
#   inflating: val/74826_sat.jpg
#   inflating: val/74833_sat.jpg
#   inflating: val/74838_sat.jpg
#   inflating: val/74844_sat.jpg
#   inflating: val/74853_sat.jpg
#   inflating: val/74861_sat.jpg
#   inflating: val/74863_sat.jpg
#   inflating: val/74872_sat.jpg
#   inflating: val/74878_sat.jpg
#   inflating: val/74887_sat.jpg
#   inflating: val/74892_sat.jpg
#   inflating: val/74893_sat.jpg
#   inflating: val/74901_sat.jpg
#   inflating: val/74902_sat.jpg
#   inflating: val/74908_sat.jpg
#   inflating: val/74914_sat.jpg
#   inflating: val/74922_sat.jpg
#   inflating: val/74927_sat.jpg
#   inflating: val/74928_sat.jpg
#   inflating: val/74932_sat.jpg
#   inflating: val/74937_sat.jpg
#   inflating: val/74941_sat.jpg
#   inflating: val/74949_sat.jpg
# ...
#   inflating: train/9116_sat.jpg
#   inflating: train/9120_msk.png
#   inflating: train/9120_sat.jpg
#   inflating: train/9124_msk.png
#   inflating: train/9124_sat.jpg
#   inflating: train/9130_msk.png
#   inflating: train/9130_sat.jpg
#   inflating: train/9138_msk.png
#   inflating: train/9138_sat.jpg
#   inflating: train/9146_msk.png
#   inflating: train/9146_sat.jpg
#   inflating: train/9149_msk.png
#   inflating: train/9149_sat.jpg
#   inflating: train/9155_msk.png
#   inflating: train/9155_sat.jpg
#   inflating: train/915_msk.png
#   inflating: train/915_sat.jpg
#   inflating: train/9161_msk.png
#   inflating: train/9161_sat.jpg
#   inflating: train/9163_msk.png
#   inflating: train/9163_sat.jpg
#   inflating: train/9167_msk.png
#   inflating: train/9167_sat.jpg
#   inflating: train/9175_msk.png
#   inflating: train/9175_sat.jpg
#   inflating: train/9176_msk.png
#   inflating: train/9176_sat.jpg
#   inflating: train/9181_msk.png
#   inflating: train/9181_sat.jpg
#   inflating: train/9186_msk.png
#   inflating: train/9186_sat.jpg
#   inflating: train/9189_msk.png
#   inflating: train/9189_sat.jpg
#   inflating: train/9196_msk.png
#   inflating: train/9196_sat.jpg
#   inflating: train/9200_msk.png
#   inflating: train/9200_sat.jpg
#   inflating: train/9206_msk.png
#   inflating: train/9206_sat.jpg
#   inflating: train/9208_msk.png
#   inflating: train/9208_sat.jpg
#   inflating: train/9210_msk.png
#   inflating: train/9210_sat.jpg
#   inflating: train/9218_msk.png
#   inflating: train/9218_sat.jpg
#   inflating: train/9222_msk.png
#   inflating: train/9222_sat.jpg
#   inflating: train/9225_msk.png
#   inflating: train/9225_sat.jpg
#   inflating: train/9230_msk.png
#   inflating: train/9230_sat.jpg
#   inflating: train/9239_msk.png
#   inflating: train/9239_sat.jpg
#   inflating: train/923_msk.png
#   inflating: train/923_sat.jpg
#   inflating: train/9242_msk.png
#   inflating: train/9242_sat.jpg
#   inflating: train/9248_msk.png
#   inflating: train/9248_sat.jpg
#   inflating: train/9253_msk.png
#   inflating: train/9253_sat.jpg
#   inflating: train/9257_msk.png
#   inflating: train/9257_sat.jpg
#   inflating: train/9264_msk.png
#   inflating: train/9264_sat.jpg
#   inflating: train/9266_msk.png
#   inflating: train/9266_sat.jpg
#   inflating: train/9269_msk.png
#   inflating: train/9269_sat.jpg
#   inflating: train/9278_msk.png
#   inflating: train/9278_sat.jpg
#   inflating: train/927_msk.png
#   inflating: train/927_sat.jpg
#   inflating: train/9287_msk.png
#   inflating: train/9287_sat.jpg
#   inflating: train/9295_msk.png
#   inflating: train/9295_sat.jpg
#   inflating: train/9296_msk.png
#   inflating: train/9296_sat.jpg
#   inflating: train/9302_msk.png
#   inflating: train/9302_sat.jpg
#   inflating: train/9306_msk.png
#   inflating: train/9306_sat.jpg
#   inflating: train/9307_msk.png
#   inflating: train/9307_sat.jpg
#   inflating: train/9311_msk.png
#   inflating: train/9311_sat.jpg
#   inflating: train/9319_msk.png
#   inflating: train/9319_sat.jpg
#   inflating: train/9320_msk.png
#   inflating: train/9320_sat.jpg
#   inflating: train/9327_msk.png
#   inflating: train/9327_sat.jpg
#   inflating: train/9332_msk.png
#   inflating: train/9332_sat.jpg
#   inflating: train/9334_msk.png
#   inflating: train/9334_sat.jpg
#   inflating: train/9339_msk.png
#   inflating: train/9339_sat.jpg
#   inflating: train/933_msk.png
#   inflating: train/933_sat.jpg
#   inflating: train/9343_msk.png
#   inflating: train/9343_sat.jpg
#   inflating: train/9347_msk.png
#   inflating: train/9347_sat.jpg
#   inflating: train/9350_msk.png
#   inflating: train/9350_sat.jpg
#   inflating: train/9354_msk.png
#   inflating: train/9354_sat.jpg
#   inflating: train/935_msk.png
#   inflating: train/935_sat.jpg
#   inflating: train/9360_msk.png
#   inflating: train/9360_sat.jpg
#   inflating: train/9364_msk.png
#   inflating: train/9364_sat.jpg
#   inflating: train/9372_msk.png
#   inflating: train/9372_sat.jpg
#   inflating: train/9378_msk.png
#   inflating: train/9378_sat.jpg
#   inflating: train/9386_msk.png
#   inflating: train/9386_sat.jpg
#   inflating: train/9393_msk.png
#   inflating: train/9393_sat.jpg
#   inflating: train/9400_msk.png
#   inflating: train/9400_sat.jpg
#   inflating: train/9401_msk.png
#   inflating: train/9401_sat.jpg
#   inflating: train/9402_msk.png
#   inflating: train/9402_sat.jpg
#   inflating: train/9404_msk.png
#   inflating: train/9404_sat.jpg
#   inflating: train/9406_msk.png
#   inflating: train/9406_sat.jpg
#   inflating: train/9408_msk.png
#   inflating: train/9408_sat.jpg
#   inflating: train/940_msk.png
#   inflating: train/940_sat.jpg
#   inflating: train/9413_msk.png
#   inflating: train/9413_sat.jpg
#   inflating: train/9420_msk.png
#   inflating: train/9420_sat.jpg
#   inflating: train/9426_msk.png
#   inflating: train/9426_sat.jpg
#   inflating: train/9431_msk.png
#   inflating: train/9431_sat.jpg
#   inflating: train/9438_msk.png
#   inflating: train/9438_sat.jpg
#   inflating: train/9447_msk.png
#   inflating: train/9447_sat.jpg
#   inflating: train/9454_msk.png
#   inflating: train/9454_sat.jpg
#   inflating: train/9455_msk.png
#   inflating: train/9455_sat.jpg
#   inflating: train/9457_msk.png
#   inflating: train/9457_sat.jpg
#   inflating: train/945_msk.png
#   inflating: train/945_sat.jpg
#   inflating: train/9462_msk.png
#   inflating: train/9462_sat.jpg
#   inflating: train/9464_msk.png
#   inflating: train/9464_sat.jpg
#   inflating: train/9467_msk.png
#   inflating: train/9467_sat.jpg
#   inflating: train/9469_msk.png
#   inflating: train/9469_sat.jpg
#   inflating: train/9475_msk.png
#   inflating: train/9475_sat.jpg
#   inflating: train/9477_msk.png
#   inflating: train/9477_sat.jpg
#   inflating: train/9484_msk.png
#   inflating: train/9484_sat.jpg
#   inflating: train/9492_msk.png
#   inflating: train/9492_sat.jpg
#   inflating: train/9493_msk.png
#   inflating: train/9493_sat.jpg
#   inflating: train/9494_msk.png
#   inflating: train/9494_sat.jpg
#   inflating: train/9499_msk.png
#   inflating: train/9499_sat.jpg
#   inflating: train/9507_msk.png
#   inflating: train/9507_sat.jpg
#   inflating: train/9509_msk.png
#   inflating: train/9509_sat.jpg
#   inflating: train/9516_msk.png
#   inflating: train/9516_sat.jpg
#   inflating: train/9523_msk.png
#   inflating: train/9523_sat.jpg
#   inflating: train/9528_msk.png
#   inflating: train/9528_sat.jpg
#   inflating: train/9533_msk.png
#   inflating: train/9533_sat.jpg
#   inflating: train/9535_msk.png
#   inflating: train/9535_sat.jpg
#   inflating: train/9543_msk.png
#   inflating: train/9543_sat.jpg
#   inflating: train/9546_msk.png
#   inflating: train/9546_sat.jpg
#   inflating: train/9547_msk.png
#   inflating: train/9547_sat.jpg
#   inflating: train/954_msk.png
#   inflating: train/954_sat.jpg
#   inflating: train/9556_msk.png
#   inflating: train/9556_sat.jpg
#   inflating: train/9561_msk.png
#   inflating: train/9561_sat.jpg
#   inflating: train/9567_msk.png
#   inflating: train/9567_sat.jpg
#   inflating: train/9571_msk.png
#   inflating: train/9571_sat.jpg
#   inflating: train/9573_msk.png
#   inflating: train/9573_sat.jpg
#   inflating: train/9582_msk.png
#   inflating: train/9582_sat.jpg
#   inflating: train/9584_msk.png
#   inflating: train/9584_sat.jpg
#   inflating: train/9592_msk.png
#   inflating: train/9592_sat.jpg
#   inflating: train/9596_msk.png
#   inflating: train/9596_sat.jpg
#   inflating: train/959_msk.png
#   inflating: train/959_sat.jpg
#   inflating: train/9603_msk.png
#   inflating: train/9603_sat.jpg
#   inflating: train/9612_msk.png
#   inflating: train/9612_sat.jpg
#   inflating: train/9613_msk.png
#   inflating: train/9613_sat.jpg
#   inflating: train/9617_msk.png
#   inflating: train/9617_sat.jpg
#   inflating: train/961_msk.png
#   inflating: train/961_sat.jpg
#   inflating: train/9626_msk.png
#   inflating: train/9626_sat.jpg
#   inflating: train/9632_msk.png
#   inflating: train/9632_sat.jpg
#   inflating: train/9635_msk.png
#   inflating: train/9635_sat.jpg
#   inflating: train/9636_msk.png
#   inflating: train/9636_sat.jpg
#   inflating: train/9637_msk.png
#   inflating: train/9637_sat.jpg
#   inflating: train/9643_msk.png
#   inflating: train/9643_sat.jpg
#   inflating: train/9649_msk.png
#   inflating: train/9649_sat.jpg
#   inflating: train/9652_msk.png
#   inflating: train/9652_sat.jpg
#   inflating: train/9658_msk.png
#   inflating: train/9658_sat.jpg
#   inflating: train/9665_msk.png
#   inflating: train/9665_sat.jpg
#   inflating: train/9667_msk.png
#   inflating: train/9667_sat.jpg
#   inflating: train/9674_msk.png
#   inflating: train/9674_sat.jpg
#   inflating: train/9683_msk.png
#   inflating: train/9683_sat.jpg
#   inflating: train/9684_msk.png
#   inflating: train/9684_sat.jpg
#   inflating: train/9688_msk.png
#   inflating: train/9688_sat.jpg
#   inflating: train/968_msk.png
#   inflating: train/968_sat.jpg
#   inflating: train/9697_msk.png
#   inflating: train/9697_sat.jpg
#   inflating: train/9699_msk.png
#   inflating: train/9699_sat.jpg
#   inflating: train/96_msk.png
#   inflating: train/96_sat.jpg
#   inflating: train/9708_msk.png
#   inflating: train/9708_sat.jpg
#   inflating: train/9713_msk.png
#   inflating: train/9713_sat.jpg
#   inflating: train/9718_msk.png
#   inflating: train/9718_sat.jpg
#   inflating: train/9726_msk.png
#   inflating: train/9726_sat.jpg
#   inflating: train/9732_msk.png
#   inflating: train/9732_sat.jpg
#   inflating: train/9733_msk.png
#   inflating: train/9733_sat.jpg
#   inflating: train/9734_msk.png
#   inflating: train/9734_sat.jpg
#   inflating: train/9735_msk.png
#   inflating: train/9735_sat.jpg
#   inflating: train/9739_msk.png
#   inflating: train/9739_sat.jpg
#   inflating: train/9741_msk.png
#   inflating: train/9741_sat.jpg
#   inflating: train/9742_msk.png
#   inflating: train/9742_sat.jpg
#   inflating: train/9747_msk.png
#   inflating: train/9747_sat.jpg
#   inflating: train/9751_msk.png
#   inflating: train/9751_sat.jpg
#   inflating: train/9759_msk.png
#   inflating: train/9759_sat.jpg
#   inflating: train/9761_msk.png
#   inflating: train/9761_sat.jpg
#   inflating: train/9766_msk.png
#   inflating: train/9766_sat.jpg
#   inflating: train/976_msk.png
#   inflating: train/976_sat.jpg
#   inflating: train/9771_msk.png
#   inflating: train/9771_sat.jpg
#   inflating: train/9779_msk.png
#   inflating: train/9779_sat.jpg
#   inflating: train/9780_msk.png
#   inflating: train/9780_sat.jpg
#   inflating: train/9782_msk.png
#   inflating: train/9782_sat.jpg
#   inflating: train/9789_msk.png
#   inflating: train/9789_sat.jpg
#   inflating: train/9797_msk.png
#   inflating: train/9797_sat.jpg
#   inflating: train/97_msk.png
#   inflating: train/97_sat.jpg
#   inflating: train/9802_msk.png
#   inflating: train/9802_sat.jpg
#   inflating: train/9806_msk.png
#   inflating: train/9806_sat.jpg
#   inflating: train/9810_msk.png
#   inflating: train/9810_sat.jpg
#   inflating: train/9812_msk.png
#   inflating: train/9812_sat.jpg
#   inflating: train/981_msk.png
#   inflating: train/981_sat.jpg
#   inflating: train/9820_msk.png
#   inflating: train/9820_sat.jpg
#   inflating: train/9821_msk.png
#   inflating: train/9821_sat.jpg
#   inflating: train/9825_msk.png
#   inflating: train/9825_sat.jpg
#   inflating: train/9833_msk.png
#   inflating: train/9833_sat.jpg
#   inflating: train/9837_msk.png
#   inflating: train/9837_sat.jpg
#   inflating: train/9841_msk.png
#   inflating: train/9841_sat.jpg
#   inflating: train/9845_msk.png
#   inflating: train/9845_sat.jpg
#   inflating: train/9851_msk.png
#   inflating: train/9851_sat.jpg
#   inflating: train/9853_msk.png
#   inflating: train/9853_sat.jpg
#   inflating: train/9855_msk.png
#   inflating: train/9855_sat.jpg
#   inflating: train/9860_msk.png
#   inflating: train/9860_sat.jpg
#   inflating: train/9862_msk.png
#   inflating: train/9862_sat.jpg
#   inflating: train/9871_msk.png
#   inflating: train/9871_sat.jpg
#   inflating: train/9876_msk.png
#   inflating: train/9876_sat.jpg
#   inflating: train/9881_msk.png
#   inflating: train/9881_sat.jpg
#   inflating: train/9884_msk.png
#   inflating: train/9884_sat.jpg
#   inflating: train/988_msk.png
#   inflating: train/988_sat.jpg
#   inflating: train/9891_msk.png
#   inflating: train/9891_sat.jpg
#   inflating: train/9898_msk.png
#   inflating: train/9898_sat.jpg
#   inflating: train/9899_msk.png
#   inflating: train/9899_sat.jpg
#   inflating: train/98_msk.png
#   inflating: train/98_sat.jpg
#   inflating: train/9904_msk.png
#   inflating: train/9904_sat.jpg
#   inflating: train/9905_msk.png
#   inflating: train/9905_sat.jpg
#   inflating: train/9908_msk.png
#   inflating: train/9908_sat.jpg
#   inflating: train/9912_msk.png
#   inflating: train/9912_sat.jpg
#   inflating: train/9915_msk.png
#   inflating: train/9915_sat.jpg
#   inflating: train/9917_msk.png
#   inflating: train/9917_sat.jpg
#   inflating: train/9923_msk.png
#   inflating: train/9923_sat.jpg
#   inflating: train/9931_msk.png
#   inflating: train/9931_sat.jpg
#   inflating: train/9940_msk.png
#   inflating: train/9940_sat.jpg
#   inflating: train/9944_msk.png
#   inflating: train/9944_sat.jpg
#   inflating: train/9947_msk.png
#   inflating: train/9947_sat.jpg
#   inflating: train/9956_msk.png
#   inflating: train/9956_sat.jpg
#   inflating: train/9957_msk.png
#   inflating: train/9957_sat.jpg
#   inflating: train/9958_msk.png
#   inflating: train/9958_sat.jpg
#   inflating: train/9961_msk.png
#   inflating: train/9961_sat.jpg
#   inflating: train/9962_msk.png
#   inflating: train/9962_sat.jpg
#   inflating: train/9967_msk.png
#   inflating: train/9967_sat.jpg
#   inflating: train/996_msk.png
#   inflating: train/996_sat.jpg
#   inflating: train/9972_msk.png
#   inflating: train/9972_sat.jpg
#   inflating: train/9977_msk.png
#   inflating: train/9977_sat.jpg
#   inflating: train/9984_msk.png
#   inflating: train/9984_sat.jpg
#   inflating: train/998_msk.png
#   inflating: train/998_sat.jpg
#   inflating: train/9990_msk.png
#   inflating: train/9990_sat.jpg
#   inflating: train/9991_msk.png
#   inflating: train/9991_sat.jpg
#   inflating: train/9997_msk.png
#   inflating: train/9997_sat.jpg
#   inflating: train/999_msk.png
#   inflating: train/999_sat.jpg

# %%
from glob import glob
import os

path_to_train = './train'
glob_train_imgs = os.path.join(path_to_train, '*_sat.jpg')
glob_train_masks = os.path.join(path_to_train, '*_msk.png')

train_img_paths = glob(glob_train_imgs)
train_mask_paths = glob(glob_train_masks)
print(train_img_paths[:10])
print(train_mask_paths[:10])
# Out:
# ['./train/12704_sat.jpg', './train/27957_sat.jpg', './train/24224_sat.jpg', './train/42647_sat.jpg', './train/48369_sat.jpg', './train/10863_sat.jpg', './train/10891_sat.jpg', './train/45931_sat.jpg', './train/21983_sat.jpg', './train/45408_sat.jpg']
# ['./train/21999_msk.png', './train/39719_msk.png', './train/8565_msk.png', './train/23164_msk.png', './train/10831_msk.png', './train/30861_msk.png', './train/7566_msk.png', './train/37626_msk.png', './train/14418_msk.png', './train/1621_msk.png']

# %%
from skimage.io import imread
from skimage.transform import resize
from skimage.color import rgb2gray

def get_img_id(img_path):
  img_basename = os.path.basename(img_path)
  img_id = os.path.splitext(img_basename)[0][:-len('_sat')]
  return img_id

def img_gen(img_paths, img_size=(512, 512)):
  #Iterate over all image paths
  for img_path in img_paths:
    img_id = get_img_id(img_path)
    mask_path = os.path.join(path_to_train,img_id+'_msk.png')
    
    img = imread(img_path)/255
    mask = rgb2gray(imread(mask_path))
    
#     img = resize(img, img_size, preserve_range = True)
#     mask = resize(mask, img_size, mode='constant', preserve_range = True)
    
    mask = (mask>=0.5).astype(float)
    mask = np.reshape(mask, (512,512,1))
    yield img, mask

# %%
import pandas as pd
import os
import csv
import os
from glob import glob
from skimage.io import imread, imsave
import numpy as np

from glob import glob
import os

path_to_train = '../../data/train/'
glob_train_imgs = os.path.join(path_to_train, '*_sat.jpg')
glob_train_masks = os.path.join(path_to_train, '*_msk.png')

train_img_paths = glob(glob_train_imgs)
train_mask_paths = glob(glob_train_masks)
print(train_img_paths[:10])
print(train_mask_paths[:10])

from skimage.io import imread
from skimage.transform import resize
from skimage.color import rgb2gray


def get_img_id(img_path):
    img_basename = os.path.basename(img_path)
    img_id = os.path.splitext(img_basename)[0][:-len('_sat')]
    return img_id


def img_gen(img_paths, img_size=(512, 512)):
    # Iterate over all image paths
    for img_path in img_paths:
        img_id = get_img_id(img_path)
        mask_path = os.path.join(path_to_train, img_id + '_msk.png')

        img = imread(img_path) / 255
        mask = rgb2gray(imread(mask_path))

        #     img = resize(img, img_size, preserve_range = True)
        #     mask = resize(mask, img_size, mode='constant', preserve_range = True)

        mask = (mask >= 0.5).astype(float)
        mask = np.reshape(mask, (512, 512, 1))
        yield img, mask


def get_non_outlier_data(train_img_paths):
    train_path_without_outlier = []
    for index, image_path in enumerate(train_img_paths):
        if index % 500 == 0:
            print(index)
        img_id = get_img_id(image_path)
        mask_path = os.path.join('../../data/train/', img_id + '_msk.png')
        mask = rgb2gray(imread(mask_path))
        if len(np.where(mask.flatten() != 0)[0]) != 0:
            train_path_without_outlier.append(image_path)
    return train_path_without_outlier


train_img_paths = get_non_outlier_data(train_img_paths)
import numpy as np


# Keras takes its input in batches
# (i.e. a batch size of 32 would correspond to 32 images and 32 masks from the generator)

# The generator should run forever
def image_batch_generator(img_paths, batchsize=32):
    while True:
        ig = img_gen(img_paths)
        batch_img, batch_mask = [], []

        for img, mask in ig:
            # Add the image and mask to the batch
            batch_img.append(img)
            batch_mask.append(mask)
            # If we've reached our batchsize, yield the batch and reset
            if len(batch_img) == batchsize:
                yield np.stack(batch_img, axis=0), np.stack(batch_mask, axis=0)
                batch_img, batch_mask = [], []

        # If we have an nonempty batch left, yield it out and reset
        if len(batch_img) != 0:
            yield np.stack(batch_img, axis=0), np.stack(batch_mask, axis=0)
            batch_img, batch_mask = [], []

from sklearn.model_selection import train_test_split

BATCHSIZE = 1

# Split the data into a train and validation set
train_img_paths, val_img_paths = train_test_split(train_img_paths, test_size=0.1,random_state=42)
print(len(train_img_paths))
print(len(val_img_paths))

# Create the train and validation generators
traingen = image_batch_generator(train_img_paths, batchsize=BATCHSIZE)
valgen = image_batch_generator(val_img_paths, batchsize=BATCHSIZE)
print(next(traingen)[0].shape)
def calc_steps(data_len, batchsize):
    return (data_len + batchsize - 1) // batchsize

# Calculate the steps per epoch
train_steps = calc_steps(len(train_img_paths), BATCHSIZE)
val_steps = calc_steps(len(val_img_paths), BATCHSIZE)
print("train steps {}".format(train_steps))
print("val steps {}".format(val_steps))

import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import *
from keras import backend as K

import tensorflow as tf

# Build U-Net model
inputs = Input((512, 512, 3))
s = inputs

c0 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(inputs)
c0 = Dropout(0.1)(c0)
c0 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c0)
p0 = MaxPooling2D((2, 2))(c0)

c1 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p0)
c1 = Dropout(0.1)(c1)
c1 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c1)
p1 = MaxPooling2D((2, 2))(c1)

c2 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p1)
c2 = Dropout(0.1)(c2)
c2 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c2)
p2 = MaxPooling2D((2, 2))(c2)

c3 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p2)
c3 = Dropout(0.2)(c3)
c3 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c3)
p3 = MaxPooling2D((2, 2))(c3)

c4 = Conv2D(512, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p3)
c4 = Dropout(0.3)(c4)
c4 = Conv2D(512, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c4)
p4 = MaxPooling2D(pool_size=(2, 2))(c4)

c5 = Conv2D(1024, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p4)
c5 = Dropout(0.5)(c5)
c5 = Conv2D(1024, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c5)

u6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(512, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u6)
c6 = Dropout(0.3)(c6)
c6 = Conv2D(512, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c6)

u7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u7)
c7 = Dropout(0.2)(c7)
c7 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c7)

u8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u8)
c8 = Dropout(0.1)(c8)
c8 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c8)

u9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = concatenate([u9, c1])
c9 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u9)
c9 = Dropout(0.1)(c9)
c9 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c9)

u10 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c9)
u10 = concatenate([u10, c0], axis=3)
c10 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u10)
c10 = Dropout(0.1)(c10)
c10 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c10)

outputs = Conv2D(1, (1, 1), activation='sigmoid')(c10)

import keras.backend as K
from keras.optimizers import Adam
from keras.losses import binary_crossentropy

smooth = 1e-9


# This is the competition metric implemented using Keras
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * (K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score


# We'll construct a Keras Loss that incorporates the DICE score
def dice_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1. - (2. * intersection + 1.) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.)


def bce_dice_loss(y_true, y_pred):
    return 0.5 * binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)


def ln_dice(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * (K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return K.log(score)


def new_bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - ln_dice(y_true, y_pred)


model = Model(inputs=[inputs], outputs=[outputs])
model.compile(Adam(1e-4), loss=bce_dice_loss, metrics=[dice_coef])
model.summary()
MODEL_NAME = 'nonblack_13layer-{epoch:02d}-{val_loss:.4f}-id7.h5'
import math
checkpointer = ModelCheckpoint(MODEL_NAME, verbose=1,monitor='val_loss', save_best_only=True)
def step_decay(epoch):
   initial_lrate = 1e-4
   drop = 0.5
   epochs_drop = 15.0
   lrate = initial_lrate * math.pow(drop,
           math.floor((1+epoch)/epochs_drop))
   return lrate
lrate = LearningRateScheduler(step_decay)
EPOCH_NUM = 60
# Train the model
history = model.fit_generator(
    traingen,
    steps_per_epoch=train_steps,
    epochs=EPOCH_NUM, # Change this to a larger number to train for longer
    validation_data=valgen,
    validation_steps=val_steps,
    verbose=1,
    max_queue_size=5,  # Change this number based on memory restrictions
    callbacks = [checkpointer,lrate]
)

# %%
from sklearn.model_selection import train_test_split

# Split the data into a train and validation set
train_img_paths, val_img_paths = train_test_split(train_img_paths, test_size=0.1, random_state = 42)
print(len(train_img_paths))
print(len(val_img_paths))

# Create the train and validation generators
traingen = image_batch_generator(train_img_paths, batchsize=BATCHSIZE)
valgen = image_batch_generator(val_img_paths, batchsize=BATCHSIZE)
print(next(traingen)[0].shape)
def calc_steps(data_len, batchsize):
    return (data_len + batchsize - 1) // batchsize

# Calculate the steps per epoch
train_steps = calc_steps(len(train_img_paths), BATCHSIZE)
val_steps = calc_steps(len(val_img_paths), BATCHSIZE)
print("train steps {}".format(train_steps))
print("val steps {}".format(val_steps))
# Out:
# 9807
# 1090
# (21, 512, 512, 3)
# train steps 467
# val steps 52

# %%
# !pip install tqdm
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import *
from keras import backend as K

import tensorflow as tf
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.28.1)

# %%
  
# Build U-Net model
inputs = Input((512, 512, 3))
s = inputs

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

import keras.backend as K
from keras.optimizers import Adam
from keras.losses import binary_crossentropy

smooth = 1e-9

# This is the competition metric implemented using Keras
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * (K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

# We'll construct a Keras Loss that incorporates the DICE score
def dice_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1. - (2. * intersection + 1.) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.)


def bce_dice_loss(y_true, y_pred):
    return 0.5 * binary_crossentropy(y_true, y_pred) + 0.5 * dice_loss(y_true, y_pred)
  
def ln_dice(y_true, y_pred):
  y_true_f = K.flatten(y_true)
  y_pred = K.cast(y_pred, 'float32')
  y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
  intersection = y_true_f * y_pred_f
  score = 2. * (K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
  return K.log(score)

def new_bce_dice_loss(y_true, y_pred):
  return binary_crossentropy(y_true, y_pred) - ln_dice(y_true, y_pred)
  

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss=bce_dice_loss, metrics=[dice_coef])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 512, 512, 16) 448         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 512, 512, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 512, 512, 16) 2320        dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 256, 256, 16) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 32) 4640        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 256, 256, 32) 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 32) 9248        dropout_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 18496       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 128, 128, 64) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 64) 36928       dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 128)  73856       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 64, 64, 128)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 128)  147584      dropout_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 256)  295168      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 256)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 256)  590080      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 128)  131200      conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_5[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 128)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 128)  147584      dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_6[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128, 128, 64) 0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 64) 36928       dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 32) 8224        conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 256, 256, 32) 0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 32) 9248        dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 512, 512, 16) 2064        conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 512, 512, 32) 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 512, 512, 16) 4624        concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512, 512, 16) 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 512, 512, 16) 2320        dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 512, 512, 1)  17          conv2d_37[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from __future__ import absolute_import
from __future__ import print_function

import keras
from keras import backend as K
import numpy as np


class LossLearningRateScheduler(keras.callbacks.History):
    """
    A learning rate scheduler that relies on changes in loss function
    value to dictate whether learning rate is decayed or not.
    LossLearningRateScheduler has the following properties:
    base_lr: the starting learning rate
    lookback_epochs: the number of epochs in the past to compare with the loss function at the current epoch to determine if progress is being made.
    decay_threshold / decay_multiple: if loss function has not improved by a factor of decay_threshold * lookback_epochs, then decay_multiple will be applied to the learning rate.
    spike_epochs: list of the epoch numbers where you want to spike the learning rate.
    spike_multiple: the multiple applied to the current learning rate for a spike.
    """

    def __init__(self, base_lr, lookback_epochs, spike_epochs = None, spike_multiple = 10, decay_threshold = 0.002, decay_multiple = 0.5, loss_type = 'val_loss'):

        super(LossLearningRateScheduler, self).__init__()

        self.base_lr = base_lr
        self.lookback_epochs = lookback_epochs
        self.spike_epochs = spike_epochs
        self.spike_multiple = spike_multiple
        self.decay_threshold = decay_threshold
        self.decay_multiple = decay_multiple
        self.loss_type = loss_type


    def on_epoch_begin(self, epoch, logs=None):
        
        if len(self.epoch) > self.lookback_epochs:

            current_lr = K.get_value(self.model.optimizer.lr)

            target_loss = self.history[self.loss_type] 

            loss_diff =  target_loss[-int(self.lookback_epochs)] - target_loss[-1]

            if loss_diff < 0:
                
                print(' '.join(('Changing learning rate from', str(current_lr), 'to', str(current_lr * self.decay_multiple))))
                K.set_value(self.model.optimizer.lr, current_lr * self.decay_multiple)
                current_lr = current_lr * self.decay_multiple

            else:

                print(' '.join(('Learning rate:', str(current_lr))))

            if self.spike_epochs is not None and len(self.epoch) in self.spike_epochs:
                print(' '.join(('Spiking learning rate from', str(current_lr), 'to', str(current_lr * self.spike_multiple))))
                K.set_value(self.model.optimizer.lr, current_lr * self.spike_multiple)

        else:

            print(' '.join(('Setting learning rate to', str(self.base_lr))))
            K.set_value(self.model.optimizer.lr, self.base_lr)


        return K.get_value(self.model.optimizer.lr)

lrs = LossLearningRateScheduler(base_lr = INITIAL_LEARNING_RATE, lookback_epochs = LOOKBACK_EPOCHS)

# %%
MODEL_NAME = "unet-lr-decay-whole-aug1-{epoch:02d}-{val_loss:.4f}.h5"
checkpointer = ModelCheckpoint(MODEL_NAME, verbose=1)
tensorboard = TensorBoard(
    log_dir = "./logs/unet-deeper",
    histogram_freq = 0,
    write_graph = True,
    write_grads = True,
    write_images = False,
    embeddings_freq = 0,
    embeddings_layer_names = None,
    embeddings_metadata = None,
    embeddings_data = None,
    batch_size = BATCHSIZE,
    update_freq = "epoch"
)

# Train the model
history = model.fit_generator(
    traingen, 
    steps_per_epoch=train_steps, 
    epochs=60, # Change this to a larger number to train for longer
    validation_data=valgen, 
    validation_steps=val_steps, 
    verbose=1,
    max_queue_size=5,  # Change this number based on memory restrictions
    callbacks = [checkpointer,lrs,tensorboard]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6521c856fecd> in <module>()
#       1 MODEL_NAME = "unet-lr-decay-whole-aug1-{epoch:02d}-{val_loss:.4f}.h5"
# ----> 2 checkpointer = ModelCheckpoint(MODEL_NAME, verbose=1)
#       3 tensorboard = TensorBoard(
#       4     log_dir = "./logs/unet-deeper",
#       5     histogram_freq = 0,
#
# NameError: name 'ModelCheckpoint' is not defined
